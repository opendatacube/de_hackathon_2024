# %%
from datacube import Datacube

dc = Datacube()

# %%
dc.list_products()
# Out:
#                           name  \
# name
# cop_dem_glo_30  cop_dem_glo_30
# dep_s2_geomad    dep_s2_geomad
# s2_l2a                  s2_l2a
#
#                                                       description    license  \
# name
# cop_dem_glo_30                                Copernicus DEM 30 m       None
# dep_s2_geomad   Sentinel-2 Annual Geometric Median and Median ...  CC-BY-4.0
# s2_l2a          Sentinel-2a and Sentinel-2b imagery, processed...       None
#
#                default_crs                               default_resolution
# name
# cop_dem_glo_30   EPSG:4326  (-0.0002777777777777778, 0.0002777777777777778)
# dep_s2_geomad    EPSG:3832                                        (-10, 10)
# s2_l2a                None                                             None

# %%
datasets = dc.find_datasets(product="dep_s2_geomad")
datasets
# Out:
# [Dataset <id=4d9cad32-39ab-52d6-8804-252c528f8a7d product=dep_s2_geomad location=https://stac.staging.digitalearthpacific.org/collections/dep_s2_geomad/items/dep_s2_geomad_066_021_2023>]

# %%
data = dc.load(datasets=datasets, dask_chunks={}, measurements=["red", "green", "blue"])
data
# Out:
# <xarray.Dataset> Size: 553MB
# Dimensions:      (time: 1, y: 9600, x: 9600)
# Coordinates:
#   * time         (time) datetime64[ns] 8B 2023-07-02T11:59:59.500000
#   * y            (y) float64 77kB -1.888e+06 -1.888e+06 ... -1.984e+06
#   * x            (x) float64 77kB 3.336e+06 3.336e+06 ... 3.432e+06 3.432e+06
#     spatial_ref  int32 4B 3832
# Data variables:
#     red          (time, y, x) uint16 184MB dask.array<chunksize=(1, 9600, 9600), meta=np.ndarray>
#     green        (time, y, x) uint16 184MB dask.array<chunksize=(1, 9600, 9600), meta=np.ndarray>
#     blue         (time, y, x) uint16 184MB dask.array<chunksize=(1, 9600, 9600), meta=np.ndarray>
# Attributes:
#     crs:           EPSG:3832
#     grid_mapping:  spatial_ref

# %%
import odc.geo.xr

data.to_array().odc.explore(vmin=1000, vmax=3000)
# Out:
# ---------------------------------------------------------------------------
# GEOSException                             Traceback (most recent call last)
# Cell In[5], line 3
#       1 import odc.geo.xr
# ----> 3 data.to_array().odc.explore(vmin=1000, vmax=3000)
#
# File /opt/homebrew/lib/python3.11/site-packages/odc/geo/_xr_interop.py:659, in _wrap_op.<locals>.wrapped(*args, **kw)
#     655 @functools.wraps(method, assigned=("__doc__",))
#     656 def wrapped(*args, **kw):
#     657     # pylint: disable=protected-access
#     658     _self, *rest = args
# --> 659     return method(_self._xx, *rest, **kw)
#
# File /opt/homebrew/lib/python3.11/site-packages/odc/geo/_map.py:267, in explore(xx, map, bands, vmin, vmax, cmap, robust, tiles, attr, layer_control, resampling, map_kwds, **kwargs)
#     265 # Add to map and raise a friendly error if data has unsuitable dims
#     266 try:
# --> 267     xx.odc.add_to(
#     268         map,
#     269         cmap=cmap,
# ...
